# %%
import os
import sys
import cv2

import matplotlib.pyplot as plt

sys.path.insert(0, '..')
from loaders.datasets import AmsterdamDataset

# %%
# images = os.path.join('..', 'data', 'sample', 'images')
# annotations = os.path.join('..', 'data', 'sample')

images = os.path.join('..', 'data', 'voc-draft', 'JPEGImages')
annotations = os.path.join('..', 'processing', 'annotations.json')

data = AmsterdamDataset(images, annotations)
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!

# %%
len(data)
# Out:
# 392

# %%
data.annotations[0]
# Out:
# {'id': 0,
#  'image_id': 0,
#  'category_id': 1,
#  'segmentation': [[595.8,
#    338.9,
#    602.43,
#    361.92,
#    605.51,
#    386.48,
#    607.55,
#    394.16,
#    798.94,
#    390.06,
#    799.97,
#    377.27,
#    801.5,
#    368.06,
#    799.97,
#    364.48,
#    798.43,
#    357.82,
#    799.45,
#    350.15,
#    802.52,
#    339.91]],
#  'area': 74044.0,
#  'bbox': [596.0, 339.0, 428.0, 173.0],
#  'iscrowd': 0,
#  'attributes': {'Class': 'Quay'}}

# %%
# %matplotlib inline

for image, mask in [data[0]]:
    fig, axs = plt.subplots(1, 2)
    
    axs[0].imshow(image)
    axs[1].imshow(mask)
    
    plt.show()
    
#     break
