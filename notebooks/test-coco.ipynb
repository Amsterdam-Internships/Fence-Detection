# %%
import os
import sys
import cv2

import matplotlib.pyplot as plt

sys.path.insert(0, '..')
from loaders.datasets import COCODataset

# %%
root = os.path.join('..', 'data', 'COCO2017')
data = COCODataset(root, categories=['cat'])
# Out:
# loading annotations into memory...
# Done (t=13.28s)
# creating index...
# index created!

# %%
image, mask = data[0]

# %%
# %matplotlib inline

plt.imshow(image)
plt.show()

# %%
plt.imshow(mask)
plt.show()

# %%
len(data)
# Out:
# 4768
