# %%
import os
import sys

import pandas as pd
import matplotlib.pyplot as plt

sys.path.insert(0, '..')
from loaders.loaders import TrainDataset

# %%
root = os.path.join('..', 'data')

# %%
pd.read_table(os.path.join(root, 'objects.txt'), encoding='iso-8859-1')
# Out:
#                                                     Wordnet name   \
# wall                                                         2978
# person, individual, someone, somebody, mortal, ...           1831
# tree                                                         2855
# building, edifice                                             312
# chair                                                         471
# ...                                                           ...
# lever                                                        1438
# nail                                                         1638
# plant                                                        1906
# tassle                                                       2720
# tilt wand                                                    2772
#
#                                                      Name index   \
# wall                                                       38984
# person, individual, someone, somebody, mortal, ...         30651
# tree                                                       26930
# building, edifice                                          21367
# chair                                                      16685
# ...                                                          ...
# lever                                                          1
# nail                                                           0
# plant                                                          0
# tassle                                                         0
# tilt wand                                                      0
#
#                                                      is object counts   \
# wall                                                                49
# person, individual, someone, somebody, mortal, ...                   0
# tree                                                                 1
# building, edifice                                                    0
# chair                                                                2
# ...                                                                ...
# lever                                                                4
# nail                                                                 5
# plant                                                                5
# tassle                                                               5
# tilt wand                                                            5
#
#                                                                              is part counts   \
# wall                                                                                    wall
# person, individual, someone, somebody, mortal, ...                            people, person
# tree                                                topiary tree, topiary trees, tree, trees
# building, edifice                                                        building, buildings
# chair                                                                          chair, chairs
# ...                                                                                      ...
# lever                                                                                  lever
# nail                                                                                    nail
# plant                                                                                  plant
# tassle                                                                                tassle
# tilt wand                                                                          tilt wand
#
#                                                                                            ADE names   \
# wall                                                bars, blue, bones, brick, bricks, brown, casem...
# person, individual, someone, somebody, mortal, ...  acrobat, adult, arm, baby, baby sitting, backg...
# tree                                                apple, background, bare, brach, branch, branch...
# building, edifice                                   acropolis, aerial, air traffic control, ancien...
# chair                                               back, fabric, foam, foldable, folding, leather...
# ...                                                                                               ...
# lever                                                                                             NaN
# nail                                                                                              NaN
# plant                                                                                             NaN
# tassle                                                                                            NaN
# tilt wand                                                                                         NaN
#
#                                                                                           Attributes   \
# wall                                                                books, pane, railing, tread, wall
# person, individual, someone, somebody, mortal, ...  back, buttocks, ear, eye, gaze, hai, hair, han...
# tree                                                branch, branches, flower, fruit, leaves, sky, ...
# building, edifice                                   arcades, arch, balcony, balustrade, bars, batt...
# chair                                               apron, arm, back, back pillow, base, foot rest...
# ...                                                                                               ...
# lever                                                                             stool, swivel chair
# nail                                                                                       right hand
# plant                                                      house, plant box, plant, flora, plant life
# tassle                                                                                  blind, screen
# tilt wand                                                                               blind, screen
#
#                                                                                            Has parts   \
# wall                                                building arena, building, edifice, car, auto, ...
# person, individual, someone, somebody, mortal, ...                                                NaN
# tree                                                         car, auto, automobile, machine, motorcar
# building, edifice                                                                                 NaN
# chair                                                                                           table
# ...                                                                                               ...
# lever                                                                                             NaN
# nail                                                                                              NaN
# plant                                                                                             NaN
# tassle                                                                                            NaN
# tilt wand                                                                                         NaN
#
#                                                      Is part of
# wall                                                         NaN
# person, individual, someone, somebody, mortal, ...           NaN
# tree                                                         NaN
# building, edifice                                            NaN
# chair                                                        NaN
# ...                                                          ...
# lever                                                        NaN
# nail                                                         NaN
# plant                                                        NaN
# tassle                                                       NaN
# tilt wand                                                    NaN
#
# [1599 rows x 8 columns]

# %%
index = pd.read_pickle(os.path.join(root, 'index_ade20k.pkl'))
index.keys()
# Out:
# dict_keys(['filename', 'folder', 'objectIsPart', 'objectPresence', 'objectcounts', 'objectnames', 'proportionClassIsPart', 'scene', 'wordnet_found', 'wordnet_level1', 'wordnet_synset', 'wordnet_hypernym', 'wordnet_gloss', 'wordnet_frequency', 'description'])

# %%
index['filename'][:10]
# Out:
# ['ADE_train_00000001.jpg',
#  'ADE_train_00000002.jpg',
#  'ADE_train_00000003.jpg',
#  'ADE_train_00000004.jpg',
#  'ADE_train_00000005.jpg',
#  'ADE_train_00000006.jpg',
#  'ADE_train_00000007.jpg',
#  'ADE_train_00000008.jpg',
#  'ADE_train_00000009.jpg',
#  'ADE_train_00000010.jpg']

# %%
index['folder'][:10]
# Out:
# ['ADE20K_2021_17_01/images/ADE/training/transportation/airport_terminal',
#  'ADE20K_2021_17_01/images/ADE/training/transportation/airport_terminal',
#  'ADE20K_2021_17_01/images/ADE/training/cultural/art_gallery',
#  'ADE20K_2021_17_01/images/ADE/training/nature_landscape/badlands',
#  'ADE20K_2021_17_01/images/ADE/training/sports_and_leisure/ball_pit',
#  'ADE20K_2021_17_01/images/ADE/training/home_or_hotel/bathroom',
#  'ADE20K_2021_17_01/images/ADE/training/home_or_hotel/bathroom',
#  'ADE20K_2021_17_01/images/ADE/training/home_or_hotel/bathroom',
#  'ADE20K_2021_17_01/images/ADE/training/home_or_hotel/bathroom',
#  'ADE20K_2021_17_01/images/ADE/training/home_or_hotel/bathroom']

# %%
index['objectcounts'][:10]
# Out:
# array([  1,   0,   1,   2,  11,  75,   0,   0,   1, 128], dtype=uint8)

# %%
for dirname, fname in zip(index['folder'], index['filename']):
    
    img = plt.imread(os.path.join(root, dirname, fname))
    plt.imshow(img)
    plt.show()
    
    img = plt.imread(os.path.join(root, dirname, f'{fname.split(".")[0]}_seg.png'))
    plt.imshow(img)
    plt.show()
    
    if 'train' in fname:
        instance_dir = fname.split('.')[0]
        for instance in os.listdir(os.path.join(root, dirname, instance_dir)):
            fpath = os.path.join(root, dirname, instance_dir, instance)
            img = plt.imread(fpath)
            plt.imshow(img)
            plt.show()
        break
